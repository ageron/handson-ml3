# %% [markdown]
# <a href="https://colab.research.google.com/github/macsrc/mac-handson-ml3/blob/main/01_hello.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## MatPlotLib

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()
